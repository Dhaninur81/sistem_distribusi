# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhaninur81/sistem_distribusi/blob/main/Jawaban_Soal_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if __name__ == '__main__':
    n = int(input())
    for i in range (1, n+1):
        print(i,end='')
